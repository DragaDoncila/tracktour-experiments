# %%
import os

from tracktour_experiments.generate_dataset_summary import generate_ctc_summary

SEG_DIR = '/home/ddon0001/PhD/experiments/scaled/pre-thesis/post_merge_resolution_seg'
GT_DIR = '/home/ddon0001/PhD/data/cell_tracking_challenge/SUBMISSION/'
OUT_ROOT = '/home/ddon0001/PhD/experiments/scaled/pre-thesis/post_merge_resolution_merges'
out_csv_path = os.path.join(OUT_ROOT, 'summary.csv')

# %%
# generate_ctc_summary(SEG_DIR, out_csv_path, use_err_seg=True, gt_dir=GT_DIR)

# %%
from tracktour_experiments.generate_configs import ds_summary_to_configs
configs = ds_summary_to_configs(out_csv_path, OUT_ROOT, div_constraint=False, use_scale=True, allow_merges=True, merge_capacity=2)

# %%
for config in configs:
     config.run(compute_additional_features=True)
# Out:
# Computing candidate edges:   0%|          | 0/11 [00:00<?, ?it/s]
# Computing candidate edges: 100%|██████████| 11/11 [00:00<00:00, 1528.79it/s]
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 707 rows, 4270 columns and 12132 nonzeros
# Model fingerprint: 0x7b65d251
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 4e+02]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 33 rows and 32 columns
# Presolve time: 0.00s
# Presolved: 674 rows, 4238 columns, 12009 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.820000e+02   0.000000e+00      0s
#      340    2.4256721e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 340 iterations and 0.01 seconds (0.01 work units)
# Optimal objective  2.425672144e+03
# Building took 0.1981949806213379 seconds
# Computing candidate edges: 100%|██████████| 91/91 [00:00<00:00, 1762.64it/s]
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 4113 rows, 26497 columns and 75399 nonzeros
# Model fingerprint: 0x877c622a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-02, 1e+02]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 26 rows and 25 columns
# Presolve time: 0.03s
# Presolved: 4087 rows, 26472 columns, 75297 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier performed 0 iterations in 0.05 seconds (0.05 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2173    1.3070043e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2173 iterations and 0.05 seconds (0.06 work units)
# Optimal objective  1.307004296e+03
# Building took 1.1905875205993652 seconds
# Computing candidate edges: 100%|██████████| 91/91 [00:00<00:00, 2572.98it/s]
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 4601 rows, 29592 columns and 84203 nonzeros
# Model fingerprint: 0x982cadb8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [9e-03, 1e+02]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 25 rows and 24 columns
# Presolve time: 0.03s
# Presolved: 4576 rows, 29568 columns, 84101 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier performed 0 iterations in 0.05 seconds (0.05 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2545    2.4764152e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2545 iterations and 0.06 seconds (0.06 work units)
# Optimal objective  2.476415161e+03
# Building took 1.085644006729126 seconds
# Computing candidate edges: 100%|██████████| 91/91 [00:00<00:00, 2059.27it/s]
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 17255 rows, 110644 columns and 314814 nonzeros
# Model fingerprint: 0xae74a533
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-02, 2e+02]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 46 rows and 45 columns
# Presolve time: 0.20s
# Presolved: 17209 rows, 110599 columns, 314654 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.04s
#
# Barrier statistics:
#  AA' NZ     : 1.956e+05
#  Factor NZ  : 1.188e+06 (roughly 60 MB of memory)
#  Factor Ops : 1.618e+08 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 0.33 seconds (0.21 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    10085    2.0747285e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 10085 iterations and 0.35 seconds (0.29 work units)
# Optimal objective  2.074728511e+04
# Building took 4.1534483432769775 seconds
# Computing candidate edges: 100%|██████████| 91/91 [00:00<00:00, 1074.52it/s]
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 50821 rows, 326326 columns and 928521 nonzeros
# Model fingerprint: 0x7458d18a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-03, 2e+02]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 127 rows and 126 columns
# Presolve time: 0.44s
# Presolved: 50694 rows, 326200 columns, 928119 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.36s
#
# Barrier performed 0 iterations in 0.91 seconds (0.73 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    28755    5.6477516e+04   0.000000e+00   0.000000e+00      1s
#
# Solved in 28755 iterations and 0.97 seconds (0.94 work units)
# Optimal objective  5.647751649e+04
# Building took 12.476891279220581 seconds
# Computing candidate edges: 100%|██████████| 1375/1375 [00:00<00:00, 2683.81it/s]
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 10809 rows, 56727 columns and 159396 nonzeros
# Model fingerprint: 0x3193c8ee
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e-02, 1e+100]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 5 rows and 4 columns
# Presolve time: 0.06s
# Presolved: 10804 rows, 56723 columns, 159371 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 9.726e+04
#  Factor NZ  : 2.634e+05 (roughly 30 MB of memory)
#  Factor Ops : 7.569e+06 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 0.09 seconds (0.10 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5902    5.5725106e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 5902 iterations and 0.10 seconds (0.12 work units)
# Optimal objective  5.572510620e+04
# Building took 3.149322509765625 seconds
# Computing candidate edges: 100%|██████████| 1375/1375 [00:00<00:00, 2638.89it/s]
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 14567 rows, 79075 columns and 222681 nonzeros
# Model fingerprint: 0xe80203be
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [6e-02, 1e+100]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 27 rows and 26 columns
# Presolve time: 0.09s
# Presolved: 14540 rows, 79071 columns, 200608 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.215e+05
#  Factor NZ  : 3.313e+05 (roughly 40 MB of memory)
#  Factor Ops : 9.102e+06 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 0.13 seconds (0.15 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7588    6.8643090e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 7588 iterations and 0.15 seconds (0.17 work units)
# Optimal objective  6.864308993e+04
# Building took 3.977738618850708 seconds
# Computing candidate edges: 100%|██████████| 1763/1763 [00:00<00:00, 2679.14it/s]
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 17353 rows, 84525 columns and 236235 nonzeros
# Model fingerprint: 0x7b11ec89
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-02, 1e+100]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 17 rows and 16 columns
# Presolve time: 0.09s
# Presolved: 17336 rows, 84521 columns, 210083 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.256e+05
#  Factor NZ  : 2.766e+05 (roughly 40 MB of memory)
#  Factor Ops : 5.062e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.13 seconds (0.16 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     8854    3.2509034e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 8854 iterations and 0.15 seconds (0.19 work units)
# Optimal objective  3.250903445e+04
# Building took 4.324321031570435 seconds
# Computing candidate edges: 100%|██████████| 1763/1763 [00:00<00:00, 2130.93it/s]
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 129009 rows, 823876 columns and 2342779 nonzeros
# Model fingerprint: 0x8c0098d8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [7e-03, 2e+02]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 164 rows and 163 columns
# Presolve time: 1.08s
# Presolved: 128845 rows, 823872 columns, 2147672 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.96s
#
# Barrier performed 0 iterations in 2.29 seconds (1.90 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    70883    1.7040998e+05   0.000000e+00   0.000000e+00      3s
#
# Solved in 70883 iterations and 2.52 seconds (2.48 work units)
# Optimal objective  1.704099762e+05
# Building took 32.06949853897095 seconds
# Computing candidate edges: 100%|██████████| 299/299 [00:00<00:00, 1231.87it/s]
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 142743 rows, 920552 columns and 2619574 nonzeros
# Model fingerprint: 0x37b05468
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [8e-03, 4e+02]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 78 rows and 78 columns
# Presolve time: 1.37s
# Presolved: 142665 rows, 920474 columns, 2619353 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 1.84s
#
# Barrier performed 0 iterations in 3.50 seconds (2.28 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    77888    1.3092871e+05   0.000000e+00   0.000000e+00      4s
#
# Solved in 77888 iterations and 3.69 seconds (3.19 work units)
# Optimal objective  1.309287085e+05
# Building took 35.320287466049194 seconds
# Computing candidate edges: 100%|██████████| 299/299 [00:00<00:00, 1431.84it/s]
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 113597 rows, 732885 columns and 2085557 nonzeros
# Model fingerprint: 0x3ff376eb
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-03, 5e+02]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 67 rows and 67 columns
# Presolve time: 0.97s
# Presolved: 113530 rows, 732818 columns, 2085358 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.71s
#
# Barrier performed 0 iterations in 1.91 seconds (1.63 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    61006    1.0190029e+05   0.000000e+00   0.000000e+00      2s
#
# Solved in 61006 iterations and 2.06 seconds (2.00 work units)
# Optimal objective  1.019002872e+05
# Building took 27.574475288391113 seconds
# Computing candidate edges: 100%|██████████| 194/194 [00:00<00:00, 1629.92it/s]
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 47601 rows, 305080 columns and 868002 nonzeros
# Model fingerprint: 0xf6c37110
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-02, 4e+01]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.38s
# Presolved: 47594 rows, 305074 columns, 867958 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.27s
#
# Barrier performed 0 iterations in 0.74 seconds (0.67 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    27378    1.8463537e+04   0.000000e+00   0.000000e+00      1s
#
# Solved in 27378 iterations and 0.81 seconds (0.80 work units)
# Optimal objective  1.846353680e+04
# Building took 12.615882873535156 seconds
# Computing candidate edges: 100%|██████████| 189/189 [00:00<00:00, 1127.17it/s]
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-11850H @ 2.50GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 44747 rows, 286386 columns and 814771 nonzeros
# Model fingerprint: 0xb2a24cc0
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-02, 5e+01]
#   Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 5 rows and 4 columns
# Presolve time: 0.44s
# Presolved: 44742 rows, 286382 columns, 814736 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.44s
#
# Barrier performed 0 iterations in 0.98 seconds (0.64 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    25172    2.0650342e+04   0.000000e+00   0.000000e+00      1s
#
# Solved in 25172 iterations and 1.05 seconds (0.87 work units)
# Optimal objective  2.065034236e+04
# Building took 16.248199224472046 seconds

# %%
for config in configs:
    if os.path.exists(os.path.join(config.data_config.out_root_path, config.data_config.dataset_name, 'matched_solution.zarr')):
        print('Finished', config.data_config.dataset_name)
        continue
    print(config.data_config.dataset_name)
    # if not os.path.exists(os.path.join(config.data_config.out_root_path, config.data_config.dataset_name, 'metrics.json')):
    config.evaluate()
    # else:
    #     print('Finished', config.data_config.dataset_name)

# %% [markdown]
# - put original bandit into plots with all features to see if more features improved/made it worse
# - ws edge with fn edge associated? Can we find this?
# - why softmax entropy good but only at the end
#     - why softmax entropy at all?
