# %%
import os

from tracktour_experiments.generate_dataset_summary import generate_ctc_summary

ROOT_DIR = '/home/ddon0001/PhD/data/cell_tracking_challenge/ST/'
OUT_ROOT = '/home/ddon0001/PhD/experiments/scaled/gt_no_div_constraint/'
out_csv_path = os.path.join(OUT_ROOT, 'summary.csv')

# %%
# generate summary for GT paths
generate_ctc_summary(ROOT_DIR, out_csv_path, use_gt=True)
# Out:
# ...
# Loading TIFFs: 100%|██████████| 150/150 [00:09<00:00, 15.33it/s]
# /home/ddon0001/miniconda3/envs/trexp/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ...
# Loading TIFFs: 100%|██████████| 80/80 [00:09<00:00,  8.80it/s]
# /home/ddon0001/miniconda3/envs/trexp/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /home/ddon0001/miniconda3/envs/trexp/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /home/ddon0001/miniconda3/envs/trexp/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ...

# %%
from generate_configs import ds_summary_to_configs
configs = ds_summary_to_configs(out_csv_path, OUT_ROOT, div_constraint=False)

# %%
for config in configs:
    config.run()
